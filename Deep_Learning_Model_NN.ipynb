# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonny-T87/Food-Sales-Predictions-/blob/main/Deep_Learning_Model_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project
#
# - Jonny Tesfahun

# %% [markdown]
# ## Opening and Loading Dataset

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

# %%
filename = '/content/drive/MyDrive/DojoBootCamp/Project Files/sales_predictions.csv'
df = pd.read_csv(filename)
df_ml = df.copy()

# %%
#Google Colab Notebook and verify the data by using the df.head() command.  
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ## Cleaning Dataset

# %% [markdown]
# 1. How many rows and columns?
#
#     - I will use 12 columns. Since most of the items can be used to determine diffrent aspects of stores, products, and prices of the data. Thus, no column will be deleted. There is 8,523 rows.
#
# 2.  What are the datatypes of each variable?
#
#     - Outlet_Establishment_Year is Integer Type (1)
#     - Item_Weight, Item_Visibility, Item_MRP, Item_Outlet_Sales are Float Types (4)
#     - Item_Identifier, Item_Fat_Content, Item_Type, Outlet_Identifier, Outlet_Size, Outlet_Location_Type, Outlet_Type are Object Types (7)

# %%
df.shape
# Out:
# (8523, 12)

# %%
# Looking at data types
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Looking at more info than data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# 3. Are there duplicates? If so, drop any duplicates.
#
#   - There looks to be no duplicates in the dataset.

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 4. Identify missing values.
#   - Outlet_Size has 2,410 missing data
#   - Item_Weight has 1,463 missing data

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# 5. Decide on how to address the missing values and do it! (This requires your judgement, so explain your choice).
#
#   - I will also replace NaN for Outlet_Size with 'missing' to keep the statistical data but also show that there is no data for store size.
#
#   - I will replace NaN for Item_Weight with Mean of the column. This will keep consistency in the column and dataset.

# %%
# Replaced 'NaN' with 'Missing'
df['Outlet_Size'].fillna('Missing', inplace=True)
# Checked for any 'NaN' and showed that there was none
df['Outlet_Size'].isna().sum()
# Out:
# 0

# %%
# Finding avg mean for 'Item_Weight' and creating a key
Itm_Wght_Avg = round(df['Item_Weight'].mean(), 2)
Itm_Wght_Avg
# Out:
# 12.86

# %%
# Replaced 'NaN' with mean for 'Item_Weight' column
df['Item_Weight'].fillna(Itm_Wght_Avg, inplace=True)
# Checked for any missing data, looks good
df['Item_Weight'].isna().sum()
# Out:
# 0

# %% [markdown]
# 6. Confirm that there are no missing values after addressing them.

# %%
#Checking whole dataset for any 'NaN' and there is none
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# 7. Find and fix any inconsistent categories of data (example: fix cat, Cat, and cats so that they are consistent)
#
#   - Item_Fat_Content column has a few typo errors such as LF, low fat, Low Fat, reg, and Regular

# %%
# trying to look at unique data
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
# looking at columns that may have inconsistency 
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998     Missing               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# -- Fat Content Typo Errors

# %%
# looks like 'LF' and 'Low Fat' and 'low fat'
# And 'reg' and 'Regular' are the same
df.groupby(['Item_Fat_Content']).sum()
# Out:
#                   Item_Weight  Item_Visibility     Item_MRP  \
# Item_Fat_Content
# LF                   4048.995        21.054330   43857.1062
# Low Fat             65837.520       326.541080  717390.8394
# Regular             36784.405       200.970026  409413.1214
# low fat              1415.455         7.313655   15071.7328
# reg                  1502.780         7.764190   15948.6810
#
#                   Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Fat_Content
# LF                                   631348       6.552424e+05
# Low Fat                            10167044       1.101503e+07
# Regular                             5771667       6.457454e+06
# low fat                              223539       2.338270e+05
# reg                                  233923       2.295765e+05

# %%
# Changed 'LF' tp "Low Fat"
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('LF','Low Fat')

# %%
#Changed 'reg' to 'Regular'
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('reg','Regular')

# %%
# Changed 'low fat' to 'Low Fat'
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('low fat','Low Fat')

# %%
# Now dataset in column is consistent
df.groupby(['Item_Fat_Content']).sum()
# Out:
#                   Item_Weight  Item_Visibility     Item_MRP  \
# Item_Fat_Content
# Low Fat             71301.970       354.909065  776319.6784
# Regular             38287.185       208.734216  425361.8024
#
#                   Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Fat_Content
# Low Fat                            11021931       1.190409e+07
# Regular                             6005590       6.687031e+06

# %% [markdown]
# 8. For any numerical columns, obtain the summary statistics of each (min, max, mean)
#
#   - For more consist data and visual appeal I will round by 2 decimals columns Item_MRP & Item_Outlet_Sales
#   - To get summary statistics of each (min, max, mean) for columns will use .describe()

# %%
# Rounding 'Item_MRP' column
df['Item_MRP'] = df['Item_MRP'].round(2)

# %%
# Rounding 'Item_Outlet_Sales' column
df['Item_Outlet_Sales'] = df['Item_Outlet_Sales'].round(2)

# %%
# Rounding the 2 columns above did not change much statistically
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.858049         0.066132   140.992810                1997.831867
# std       4.226124         0.051598    62.275166                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.825000                1987.000000
# 50%      12.860000         0.053931   143.010000                1999.000000
# 75%      16.000000         0.094585   185.645000                2004.000000
# max      21.350000         0.328391   266.890000                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288926
# std          1706.499605
# min            33.290000
# 25%           834.245000
# 50%          1794.330000
# 75%          3101.300000
# max         13086.960000

# %%
# Checking it visually 
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.10            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998     Missing               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            3735.14
# 1  Supermarket Type2             443.42
# 2  Supermarket Type1            2097.27
# 3      Grocery Store             732.38
# 4  Supermarket Type1             994.71

# %% [markdown]
# 9. Extra Credit - Would like to show Item_Visibility as percentage. Just so the dataset can be more visually appealing and readable

# %%
 # Was able to change formate of column so that data shows as percentage (1.00%), It took a while
 # I got assistance from https://stackoverflow.com/questions/54110289/pandas-dataframe-column-of-floats-to-percentage-style-error
df['Item_Visibility'] = df['Item_Visibility'].astype(float).map("{:.2%}".format)

# %%
df['Item_Visibility'].head()
# Out:
# 0    1.60%
# 1    1.93%
# 2    1.68%
# 3    0.00%
# 4    0.00%
# Name: Item_Visibility, dtype: object

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content Item_Visibility  \
# 0           FDA15         9.30          Low Fat           1.60%
# 1           DRC01         5.92          Regular           1.93%
# 2           FDN15        17.50          Low Fat           1.68%
# 3           FDX07        19.20          Regular           0.00%
# 4           NCD19         8.93          Low Fat           0.00%
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.10            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998     Missing               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            3735.14
# 1  Supermarket Type2             443.42
# 2  Supermarket Type1            2097.27
# 3      Grocery Store             732.38
# 4  Supermarket Type1             994.71

# %% [markdown]
# ## Visual Exploratory Data Analysis:
#
# - Histogram to view the distributions of various features in your dataset.
# - Boxplot to view statistical summaries of various features in your dataset.
# - Heatmap of the correlation between features.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Looking for correlations

# %%
df.corr()
# Out:
#                            Item_Weight  Item_MRP  Outlet_Establishment_Year  \
# Item_Weight                   1.000000  0.024755                  -0.008447
# Item_MRP                      0.024755  1.000000                   0.005020
# Outlet_Establishment_Year    -0.008447  0.005020                   1.000000
# Item_Outlet_Sales             0.011567  0.567574                  -0.049135
#
#                            Item_Outlet_Sales
# Item_Weight                         0.011567
# Item_MRP                            0.567574
# Outlet_Establishment_Year          -0.049135
# Item_Outlet_Sales                   1.000000

# %%
# Looking at the dataset correlations or lack there of
corr = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap='Reds', annot=True);

# %%
# Using seaborn pairplot to look for any correlations with varibles 
sns.pairplot(df)

# %% [markdown]
# Histogram of Item Weight

# %%
df['Item_Weight'].hist(label='Item Weight', bins='auto')
plt.xlabel('Item Weight by Pounds')
plt.ylabel('# of Items')
plt.legend();

# %% [markdown]
# Histogram of Item MRP in $ with Red color

# %%
df['Item_MRP'].hist(bins=10, color='red', edgecolor='black')
plt.xlabel('Item MRP by $')
plt.ylabel('# of Items')
plt.xticks(rotation = 45)
plt.ticklabel_format(useOffset=False, style='plain')

# %% [markdown]
# Seaborn horizontal histogram of Store Oulet Sizes

# %%
sns.histplot(data=df, y='Outlet_Size', color='orange')
plt.xlabel('# of Outlets')
plt.ylabel('Outlet Size or Missing Data');

# %% [markdown]
# Boxplot of Item_Weight and Item_MRP

# %%
columns = ['Item_Weight', 'Item_MRP']
boxplot = df.boxplot(column=['Item_Weight', 'Item_MRP'])

# %% [markdown]
# Boxplot of Item Outlet Sales and it shows alot of outliers

# %%
boxplot = df.boxplot(column=['Item_Outlet_Sales']);

# %% [markdown]
# Comparing Item Outlet Sales to Outlet Size using seaborn boxplot

# %%
sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales',data=df, linewidth=2.5)
plt.xlabel('Outlet Sizes')
plt.ylabel('Item Outlet Sales');

# %% [markdown]
# Scatter plot of Item MRP to Item Outlet Sales. Seems to show the higher item mrp the greater the item outlet sales.

# %%
df.plot.scatter(x='Item_MRP', y='Item_Outlet_Sales')
plt.xlabel('Item MRP')
plt.ylabel('Item Outlet Sales');
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
Item_MRP_Filter = df[(df['Item_MRP'] > 100) & (df['Item_MRP'] < 200)]

# %%
Outlet_Size_Weight = df.groupby('Outlet_Size')['Item_Weight'].mean()
Outlet_Size_Weight
# Out:
# Outlet_Size
# High       13.006148
# Medium     12.883562
# Missing    12.778479
# Small      12.850712
# Name: Item_Weight, dtype: float64

# %% [markdown]
# Horizontal bar graph of Avg. Item of Product Weight compared to Store Size

# %%
plt.barh(Outlet_Size_Weight.index, Outlet_Size_Weight.values)
plt.xlabel('Avg. Item of Product Weight')
plt.ylabel('Store Size');

# %%
sns.scatterplot(data=df, x='Item_MRP', y='Item_Weight', hue='Outlet_Size');

# %% [markdown]
# ##Data Visualizations to help your stakeholders better understand trends in the data.

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content Item_Visibility  \
# 0           FDA15         9.30          Low Fat           1.60%
# 1           DRC01         5.92          Regular           1.93%
# 2           FDN15        17.50          Low Fat           1.68%
# 3           FDX07        19.20          Regular           0.00%
# 4           NCD19         8.93          Low Fat           0.00%
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.10            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998     Missing               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            3735.14
# 1  Supermarket Type2             443.42
# 2  Supermarket Type1            2097.27
# 3      Grocery Store             732.38
# 4  Supermarket Type1             994.71

# %% [markdown]
# - What is the average sales for diffrent Grocery Outlet Sizes?

# %%
Outlet_Type_Sales = df.groupby('Outlet_Type')['Item_Outlet_Sales'].mean()
Outlet_Type_Sales
# Out:
# Outlet_Type
# Grocery Store         339.828458
# Supermarket Type1    2316.181207
# Supermarket Type2    1995.498718
# Supermarket Type3    3694.038396
# Name: Item_Outlet_Sales, dtype: float64

# %%
plt.barh(Outlet_Type_Sales.index, Outlet_Type_Sales.values)
plt.xlabel('Avg. Item Sales in ($)')
plt.ylabel('Outlet Types')
plt.title('Item Sales Compared to Grocery Outlet Size');

# %% [markdown]
# - How much sales are there for Outlets in Tier 3 locations?

# %%
sns.lineplot(data=df, x='Outlet_Location_Type', y='Item_Outlet_Sales', color= 'c', ci = None, marker= 'o', markersize = 10)
plt.xlabel('Outlet Tier Locations')
plt.ylabel('Sales in $')
plt.title('Relationship between Outlet location and Sales');
#plt.tight_layout()
#plt.savefig('OutletSales_OutletLocation.jpg', dpi = 300);

# %% [markdown]
# - What are Item Sales per Store Size?

# %%
sns.set(style="darkgrid")    
sns.lineplot(
    data=df.query("Item_Outlet_Sales > 1000"),
    x="Item_Type", y="Item_Outlet_Sales", hue="Outlet_Size",
     palette="flare"
)
plt.xticks(rotation = 80)
plt.xlabel('Food Items', fontweight='bold')
plt.ylabel('Item Sales ($)', fontweight='bold')
plt.title('Outlet Size & Product Item Sales More Than 1000', fontsize = 20, fontweight = 'bold');

# %% [markdown]
# - Do Low Fat Items Cost more than Regulare Fat Items?

# %%
sns.boxplot(data=df, x='Item_Fat_Content', y='Item_MRP')
plt.title('Item Fat Content & Product Price', fontweight='bold')
plt.xlabel('Item Fat Content')
plt.ylabel('MRP in $');

# %% [markdown]
# - Do Low Fat Items have more sales than Regulare Fat Items?

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12,4))

sns.boxplot(data=df, x='Item_Fat_Content', y='Item_MRP', ax=axes[0])
axes[0].set_title('Item Fat Content & Product Price', fontweight='bold')

sns.boxplot(data=df, x='Item_Fat_Content', y='Item_Outlet_Sales', ax=axes[1])
axes[1].set_title('Item Fat Content & Product Sales', fontweight='bold')

fig.suptitle('Item Fat Content affecting Item Price & Sales', fontsize = 20, fontweight = 'bold', y=1.05);

# %% [markdown]
# - What are Product Sales and Item Prices compared to Outlet Store Sizes?

# %%
sns.scatterplot(data=df, x='Item_MRP', y='Item_Outlet_Sales', hue='Outlet_Type')
plt.legend(title='Outlet Store Type',
           bbox_to_anchor=(1.02, 1))
plt.xlabel('Items MRP in ($)')
plt.ylabel('Store Sales in ($)')
plt.title('Item Sales & Product Price by Store Size');
#plt.tight_layout()
#plt.savefig('ItemSales_per_ItemMRP.jpg', dpi = 300);

# %%
sns.set_theme()

# Load the penguins dataset
penguins = sns.load_dataset("penguins")

# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=df,
    x="Item_MRP", y="Item_Outlet_Sales", hue="Outlet_Type", height=5)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Item Store Sales ($)", "Item MRP ($)")
plt.title('Item Sales & Product Price by Store Size', fontsize = 20, fontweight = 'bold');

# %% [markdown]
# ##Interactive Visual Plots

# %%
import plotly.express as px
import cufflinks as cf
import bokeh as bk
from IPython.display import display,HTML
# !pip install chart_studio
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: chart_studio in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from chart_studio) (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chart_studio) (2.23.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2022.6.15)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   object
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 799.2+ KB

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content Item_Visibility  \
# 0           FDA15         9.30          Low Fat           1.60%
# 1           DRC01         5.92          Regular           1.93%
# 2           FDN15        17.50          Low Fat           1.68%
# 3           FDX07        19.20          Regular           0.00%
# 4           NCD19         8.93          Low Fat           0.00%
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.10            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998     Missing               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            3735.14
# 1  Supermarket Type2             443.42
# 2  Supermarket Type1            2097.27
# 3      Grocery Store             732.38
# 4  Supermarket Type1             994.71

# %% [markdown]
# Price & Sales of Meat based on Outlet Size & Type
# - smaller circles = lower MRP price
# - bigger circles = higher MRP price

# %%
fig = px.scatter(df.query("Item_Type=='Meat'"), x="Item_Outlet_Sales", y="Outlet_Size",
	         size="Item_MRP", color="Outlet_Type",
                 hover_name="Item_Identifier", log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fdd89fa7-1b11-4a20-b95e-9ce07e636a78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdd89fa7-1b11-4a20-b95e-9ce07e636a78")) {                    Plotly.newPlot(                        "fdd89fa7-1b11-4a20-b95e-9ce07e636a78",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Outlet_Type=Supermarket Type1<br>Item_Outlet_Sales=%{x}<br>Outlet_Size=%{y}<br>Item_MRP=%{marker.size}<extra></extra>","hovertext":["FDN15","FDK43","FDV27","FDH19","FDN27","FDW51","FDM15","FDV39","FDV15","FDI19","FDX15","FDA39","FDL43","FDY03","FDJ55","FDY03","FDT39","FDV51","FDL27","FDT27","FDS15","FDO51","FDH19","FDK43","FDN39","FDW03","FDK15","FDJ55","FDX39","FDQ51","FDO15","FDY03","FDP03","FDS27","FDP51","FDR27","FDX39","FDS51","FDZ39","FDJ55","FDZ39","FDU15","FDK43","FDX15","FDM51","FDH19","FDS15","FDV39","FDR03","FDR03","FDS15","FDQ03","FDP39","FDA39","FDY51","FDP39","FDL03","FDJ27","FDO27","FDQ51","FDJ55","FDL03","FDS15","FDA39","FDL43","FDT27","FDM15","FDW51","FDI07","FDT03","FDL43","FDQ39","FDJ27","FDA39","FDR15","FDI07","FDL43","FDO03","FDJ55","FDO39","FDK27","FDR27","FDW39","FDS51","FDT27","FDY51","FDV03","FDP27","FDM51","FDU39","FDP03","FDI19","FDW15","FDL27","FDU51","FDL15","FDO39","FDU15","FDX51","FDQ27","FDS27","FDU51","FDQ39","FDR39","FDP03","FDZ51","FDN03","FDM03","FDP27","FDT39","FDK55","FDR51","FDU39","FDP03","FDO27","FDW27","FDW03","FDU39","FDW39","FDQ03","FDV03","FDK43","FDM51","FDX51","FDT15","FDL03","FDQ03","FDS27","FDW03","FDV39","FDS15","FDT27","FDV03","FDG31","FDY03","FDS03","FDO15","FDW27","FDZ39","FDR15","FDX03","FDV03","FDU15","FDX15","FDZ51","FDV39","FDQ15","FDH19","FDK55","FDI07","FDQ51","FDT03","FDX51","FDZ39","FDN15","FDO39","FDQ39","FDJ27","FDV27","FDN39","FDU51","FDV15","FDM03","FDK55","FDS39","FDT03","FDU27","FDQ03","FDN51","FDU03","FDW15","FDK15","FDM15","FDR51","FDM27","FDH31","FDU51","FDK27","FDP27","FDR15","FDR15","FDJ07","FDO39","FDN15","FDT03","FDK27","FDH31","FDT15","FDR27","FDS03","FDQ27","FDT51","FDO27","FDY51","FDL27","FDX51","FDA39","FDQ15","FDG31","FDN27","FDI07","FDT39","FDU03","FDP03","FDQ15","FDM51","FDT39","FDX03","FDM27","FDZ51","FDN03","FDK55","FDX39","FDS27","FDV51","FDQ39","FDW51","FDM15","FDR27","FDS27","FDU39","FDU27","FDN51","FDU27","FDS27","FDI19","FDM51","FDG31","FDS39","FDO15","FDU15","FDU15","FDM03","FDR15","FDW03","FDI07","FDV51","FDX03","FDQ15","FDP03","FDL43","FDN51","FDR39","FDQ39","FDY39","FDR39","FDW39","FDN39","FDV39","FDI19","FDV15","FDP39","FDM15","FDX15","FDN39","FDW27","FDH31"],"legendgroup":"Supermarket Type1","marker":{"color":"#636efa","size":[141.62,126.0,87.35,172.57,117.28,214.56,151.44,198.14,103.96,242.75,160.66,40.28,75.37,110.92,225.94,110.52,151.14,165.08,66.38,233.16,108.76,41.21,175.47,128.4,168.38,105.33,98.3,226.84,212.56,45.57,72.3,111.72,125.64,197.51,119.61,131.99,210.36,61.42,101.8,226.04,101.2,37.95,127.3,159.66,102.27,172.47,106.76,196.74,205.0,207.9,107.16,238.72,52.43,40.28,220.08,53.53,197.51,100.77,94.38,48.37,223.54,196.31,107.66,41.08,77.57,234.66,152.44,213.96,196.94,185.56,76.07,192.48,103.87,39.18,153.13,196.94,76.47,230.54,223.54,182.86,119.18,134.49,176.94,61.22,232.86,220.08,154.63,188.45,102.57,58.16,125.64,243.15,149.77,65.68,175.8,152.67,184.96,34.75,195.95,103.9,197.61,178.5,190.08,182.43,121.84,93.31,249.64,106.09,190.85,152.84,87.22,151.47,58.46,122.94,94.98,156.63,105.13,57.36,175.14,235.62,154.43,126.3,102.47,195.45,184.3,194.81,238.02,197.11,106.13,196.64,106.36,233.96,153.63,63.08,111.82,63.48,73.2,156.03,104.5,153.43,44.77,156.23,36.65,162.16,96.31,197.74,81.63,173.87,89.42,199.04,48.17,183.16,196.85,102.6,139.92,185.26,190.58,103.37,90.45,167.08,178.6,103.76,107.89,89.12,143.88,184.66,47.14,238.82,261.59,182.33,146.57,100.8,149.8 ...

# %% [markdown]
# 3d scatter Visual of Item Price, Visibility, Sales Compared to Outlet Types
# - diffrent outlet types & outlet size = diffrent color & symbol
# - outlet size with values as 'Missing' were removed for less clutter

# %%
fig = px.scatter_3d(df.query("Outlet_Size !='Missing'"), x='Item_Outlet_Sales', y='Item_Visibility', z='Item_MRP',
                    color='Outlet_Type', symbol='Outlet_Size')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9788f3b7-a603-42cc-a749-0317d9aaa3af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9788f3b7-a603-42cc-a749-0317d9aaa3af")) {                    Plotly.newPlot(                        "9788f3b7-a603-42cc-a749-0317d9aaa3af",                        [{"hovertemplate":"Outlet_Type=Supermarket Type1<br>Outlet_Size=Medium<br>Item_Outlet_Sales=%{x}<br>Item_Visibility=%{y}<br>Item_MRP=%{z}<extra></extra>","legendgroup":"Supermarket Type1, Medium","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Supermarket Type1, Medium","scene":"scene","showlegend":true,"x":[3735.14,2097.27,1516.03,1589.26,718.4,3791.07,2527.38,796.96,5580.74,1207.1,1523.35,690.43,1231.73,3896.26,5942.26,2676.52,7370.41,778.99,2233.09,1661.84,4745.82,6008.84,780.98,1995.4,535.97,759.01,1237.72,925.46,4950.89,2404.2,703.08,1937.48,3307.69,3142.58,1255.7,659.14,1677.82,3707.17,5770.49,3415.55,6687.96,5642.66,588.57,1929.49,2133.22,1713.77,2336.96,4584.7,3299.7,633.84,2386.23,1238.39,1561.97,3848.32,1547.32,1045.31,1667.83,878.86,1332.93,4042.74,2478.77,5764.5,1270.35,1308.3,1488.06,5159.28,4500.81,2954.15,2756.41,1267.68,744.36,4554.07,1470.09,2924.86,960.75,5198.57,2432.83,2328.3,1867.57,3195.84,4086.01,3067.34,1470.09,2696.49,1150.5,1054.63,452.74,1565.96,6331.76,7017.53,451.41,743.03,4940.24,1998.73,1020.67,703.08,862.88,3912.24,6183.95,623.19,490.69,1584.6,2163.18,1125.2,1570.62,3428.2,1637.87,805.62,2251.74,2444.82,1713.77,1488.06,1166.48,3661.9,1177.13,3383.6,6040.14,2832.98,3769.76,1540.66,466.06,2681.84,2373.58,1853.59,540.63,1065.28,2925.53,343.55,1127.87,2993.44,1721.09,3582.0,4098.66,6353.06,4567.39,2463.46,1921.5,1647.86,792.3,769.0,2348.94,2492.76,4436.89,5954.92,1593.93,4138.61,5383.66,2577.98,7646.05,1492.72,2388.89,2050.66,1229.07,6179.96,2173.17,5285.12,1099.9,3110.62,1288.99,1893.54,6574.78,3511.43,3131.92,1478.08,793.63,1198.44,7130.72,3399.57,3653.91,3340.32,1491.39,563.93,3261.75,1114.55,404.81,5956.91,1158.49,2841.63,2876.26,1022.67,852.22,628.52,1597.92,6692.62,1148.51,3283.73,1138.52,503.34,1853.59,1328.27,2069.31,2912.88,1583.94,958.75,972.07,3605.31,2133.22,3448.84,1446.12,4054.72,2343.62,5350.37,1120.54,2612.6,3563.36,1603.25,2535.37,1657.84,1505.37,6309.79,633.84,402.81,749.02,5257.16,564.6,825.59,4633.97,3375.61,1076.6,4211.19,1431.47,490.03,3928.22,1687.14,1108.56,4958.88,755.68,3813.7,2556.67,1255.03,452.74,293.62,5105.35,1569.96,1717.76,1304.97,784.31,1205.1,3338.99,2684.51,2439.49,1907.52,640.5,3615.29,2696.49,437.43,2050.66,2345.61,1905.52,4793.76,1138.52,1251.7,3418.88,1685.81,3193.18,3243.78,3673.88,631.18,908.82,2570.65,4274.44,4042.74,1696.46,4687.23,2167.84,2749.75,512.67,2826.32,3846.99,557.27,982.06,2119.91,6381.69,649.16,1584.6,3574.01,3006.09,2972.13,2946.16,1657.18,690.43,2673.85,2524.05,4016.11,1611.24,1203.77,1448.78,2367.58,1860.25,3139.91,2656.54,1395.52,1219.75,2698.49,4544.08,2797.69,2759.08,4761.8,3275.74,934.78,1765.7,4563.39,243.68,905.49,2133.22,611.2,927.46,207.73,663.14,2239.09,1518.02,885.51,1576.61,373.51,3828.35,1733.74,5715.23,1261.69,805.62,3731.81,3068.01,870.87,1257.03,243.02,1230.4,2501.41,265.65,1185.12,856.88,2852.29,4578.04,3709.84,2293.02,3427.54,952.09,886.85,1829.62,2603.28,2073.3,3845.0,1966.77,2719.79,808.95,1845.6,2034.02,2348.94,2889.57,780.98,1603.91,5386.99,1486.73,1416.82,1274.34,805.62,4925.59,2252.4,2336.96,2797.69,3495.45,2821.66,1006.69,3046.7,1198.44,3739.13,1164.48,3962.84,1717.76,1566.63,3179.86,562.6,1174.47,552.61,3418.88,1150.5,1262.36,2246.41,1518.02,6972.26,459.4,1071.94,2087.28,4649.95,473.38,1238.39,1050.63,3323.01,1518.02,986.72,2510.07,302.94,1605.91,3068.01,5400.97,972.07,2695.16,3528.74,4757.81,820.27,320.92,1038.65,1896.2,2281.7,1822.29,2326.97,1677.15,822.26 ...

# %% [markdown]
# ##Machine Learning - Analytical

# %%
#Importing needed packages and library
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn import set_config
set_config(display='diagram')

# %%
df_ml.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
#Checking columns and dtypes
df_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#Checking for missing values. No missing values in target column
df_ml.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#Checking duplicates and no duplicates
df_ml.duplicated().sum()
# Out:
# 0

# %%
#Alot of unique values for Item_Visibility. So may take it out of the data features
#May take out Item_Identifier out also, but looks like not alot of unique values. So can be useful for machine learning but unsure
#Item MRP has high unique values but has a medium positive correlation with our target 
df_ml.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %% [markdown]
#     Since this is ordial data, i will use replacement dictionary to make =0, =1, =2 for Outlet_Size, Outlet_Location_Type, and Item Fat Content columns.
#     And change with replacment from object to number.

# %%
df_ml['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
#Since there are NaN in data, later on they will be filled with mean or median thru column transformer
Outlet_Size_dictionary = {'Small':0, 'Medium':1, 'High':2}
df_ml['Outlet_Size'].replace(Outlet_Size_dictionary, inplace=True)
df_ml['Outlet_Size'].head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    NaN
# 4    2.0
# Name: Outlet_Size, dtype: float64

# %%
df_ml['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
Outlet_Location_dictionary = {'Tier 1':0, 'Tier 2':1, 'Tier 3':2}
df_ml['Outlet_Location_Type'].replace(Outlet_Location_dictionary, inplace=True)
df_ml['Outlet_Location_Type'].head()
# Out:
# 0    0
# 1    2
# 2    0
# 3    2
# 4    2
# Name: Outlet_Location_Type, dtype: int64

# %%
# Also adding replacement dictionary to Item Fat Content due to typo errors
df_ml['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
ItemFat_Content_dictionary = {'Low Fat':0, 'LF':0, 'low fat':0, 'Regular':1, 'reg':1}
df_ml['Item_Fat_Content'].replace(ItemFat_Content_dictionary, inplace=True)
df_ml['Item_Fat_Content'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Item_Fat_Content, dtype: int64

# %%
#Looking at correlation for columns
df_ml.corr()
# Out:
#                            Item_Weight  Item_Fat_Content  Item_Visibility  \
# Item_Weight                   1.000000         -0.023238        -0.014048
# Item_Fat_Content             -0.023238          1.000000         0.047314
# Item_Visibility              -0.014048          0.047314         1.000000
# Item_MRP                      0.027141          0.006063        -0.001315
# Outlet_Establishment_Year    -0.011588          0.003151        -0.074834
# Outlet_Size                   0.011948          0.000979        -0.096773
# Outlet_Location_Type          0.004715         -0.001598        -0.028099
# Item_Outlet_Sales             0.014123          0.018719        -0.128625
#
#                            Item_MRP  Outlet_Establishment_Year  Outlet_Size  \
# Item_Weight                0.027141                  -0.011588     0.011948
# Item_Fat_Content           0.006063                   0.003151     0.000979
# Item_Visibility           -0.001315                  -0.074834    -0.096773
# Item_MRP                   1.000000                   0.005020    -0.005827
# Outlet_Establishment_Year  0.005020                   1.000000    -0.298431
# Outlet_Size               -0.005827                  -0.298431     1.000000
# Outlet_Location_Type       0.000232                  -0.089216     0.635185
# Item_Outlet_Sales          0.567574                  -0.049135     0.129076
#
#                            Outlet_Location_Type  Item_Outlet_Sales
# Item_Weight                            0.004715           0.014123
# Item_Fat_Content                      -0.001598           0.018719
# Item_Visibility                       -0.028099          -0.128625
# Item_MRP                               0.000232           0.567574
# Outlet_Establishment_Year             -0.089216          -0.049135
# Outlet_Size                            0.635185           0.129076
# Outlet_Location_Type                   1.000000           0.089367
# Item_Outlet_Sales                      0.089367           1.000000

# %%
#Looking at value counts i think it is better to drop column because may create unnecessary data
df_ml['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   int64
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   float64
#  9   Outlet_Location_Type       8523 non-null   int64
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 799.2+ KB

# %% [markdown]
#     - features matrix (X) = Item_Weight, Item_Fat_Content, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type
#     (removed  Outlet_Identifier, Outlet_Establishment_Year, and Item_Identifier because they are not useful to machine learning for this target based on low correlations)
#
#     - target (y)=  Item_Outlet_Sales
#
#     - And performing a train test split.

# %%
# Validation Split features and target 
X = df_ml.drop(columns=['Item_Outlet_Sales', 'Item_Identifier', 'Outlet_Identifier' ,'Outlet_Establishment_Year'], axis=1)
y = df_ml['Item_Outlet_Sales']
# Also Train test split the data to prepare for machine learning.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility              Item_Type  \
# 4776       16.350                 0         0.029565              Household
# 7510       15.250                 1         0.000000            Snack Foods
# 5828       12.350                 1         0.158716                   Meat
# 5327        7.975                 0         0.014628           Baking Goods
# 4810       19.350                 0         0.016645           Frozen Foods
# ...           ...               ...              ...                    ...
# 5734        9.395                 1         0.286345  Fruits and Vegetables
# 5191       15.600                 0         0.117575           Frozen Foods
# 5390       17.600                 0         0.018944     Health and Hygiene
# 860        20.350                 0         0.054363            Snack Foods
# 7270       16.350                 0         0.016993              Household
#
#       Item_MRP  Outlet_Size  Outlet_Location_Type        Outlet_Type
# 4776  256.4646          1.0                     2  Supermarket Type2
# 7510  179.7660          1.0                     2  Supermarket Type2
# 5828  157.2946          1.0                     0  Supermarket Type1
# 5327   82.3250          0.0                     1  Supermarket Type1
# 4810  120.9098          NaN                     1  Supermarket Type1
# ...        ...          ...                   ...                ...
# 5734  139.1838          NaN                     2      Grocery Store
# 5191   75.6670          NaN                     1  Supermarket Type1
# 5390  237.3590          NaN                     1  Supermarket Type1
# 860   117.9466          NaN                     1  Supermarket Type1
# 7270   95.7410          0.0                     0  Supermarket Type1
#
# [6392 rows x 8 columns]

# %% [markdown]
#     Creating a preprocessing object to prepare the dataset for Machine Learning

# %%
#Using column selectors to use with our column transformer.  
cal_selector = make_column_selector(dtype_include='object')
num_selector = make_column_selector(dtype_include='number')

# %%
# Using Scaler
scaler = StandardScaler()
# Using One-hot encoder
ohe = OneHotEncoder(handle_unknown='ignore', sparse=False)

# %%
# Using Imputers for freq, mean, and constants
freq_imputer = SimpleImputer(strategy='most_frequent')
mean_imputer = SimpleImputer(strategy='mean')

# %%
# Numeric pipeline for numbers
numeric_pipe = make_pipeline(mean_imputer, scaler)
numeric_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
# Categorical pipeline for objects
categorical_pipe = make_pipeline(freq_imputer, ohe)
categorical_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse=False))])

# %%
# Tuples for Column Transformer, number tuple, category tuple, constant tuple
number_tuple = (numeric_pipe, num_selector)
category_tuple = (categorical_pipe, cal_selector)

# %%
#Using column transformer with diagram
preprocessing = make_column_transformer(number_tuple,category_tuple)
preprocessing
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f005c32e250>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f005c32e290>)])

# %%
#fiting X_train data
preprocessing.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f005c32e250>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f005c32e290>)])

# %%
#TRansforming both the train and test data
X_train_processed = preprocessing.transform(X_train)
X_test_processed = preprocessing.transform(X_test)

# %%
#Checking array on train data, looks good.
X_train_processed
# Out:
# array([[ 0.81724868, -0.7403206 , -0.71277507, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.5563395 ,  1.35076614, -1.29105225, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.13151196,  1.35076614,  1.81331864, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.11373638, -0.7403206 , -0.92052713, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.76600931, -0.7403206 , -0.2277552 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.81724868, -0.7403206 , -0.95867683, ...,  1.        ,
#          0.        ,  0.        ]])

# %% [markdown]
#     Taking a look at the train and test data for missing values, checking dtype, and making sure shape looks fine. Everything looks good.

# %%
#Printing data for easy viewing
print(np.isnan(X_train_processed).sum().sum(), 'missing values in training data')
print(np.isnan(X_test_processed).sum().sum(), 'missing values in testing data')
print('\n')
print('All data in X_train_processed are', X_train_processed.dtype)
print('All data in X_test_processed are', X_test_processed.dtype)
print('\n')
print('shape of data is', X_train_processed.shape)
print('\n')
X_train_processed
# Out:
# 0 missing values in training data
# 0 missing values in testing data
#
#
# All data in X_train_processed are float64
# All data in X_test_processed are float64
#
#
# shape of data is (6392, 26)
# array([[ 0.81724868, -0.7403206 , -0.71277507, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.5563395 ,  1.35076614, -1.29105225, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.13151196,  1.35076614,  1.81331864, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.11373638, -0.7403206 , -0.92052713, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.76600931, -0.7403206 , -0.2277552 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.81724868, -0.7403206 , -0.95867683, ...,  1.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# ##Regression Models to Predict Outlet Sales

# %%
# Importing needed files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor #Used to test model
from sklearn.ensemble import BaggingRegressor #Used to test model
from sklearn.tree import plot_tree
from sklearn import set_config
set_config(display='diagram')

# %%
#Checking data for duplicates again
df_ml.duplicated().sum()
# Out:
# 0

# %%
#Checking dtypes
df_ml.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content               int64
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                  float64
# Outlet_Location_Type           int64
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#Checking train array
X_train_processed
# Out:
# array([[ 0.81724868, -0.7403206 , -0.71277507, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.5563395 ,  1.35076614, -1.29105225, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.13151196,  1.35076614,  1.81331864, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.11373638, -0.7403206 , -0.92052713, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.76600931, -0.7403206 , -0.2277552 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.81724868, -0.7403206 , -0.95867683, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
#Checking test array
X_test_processed
# Out:
# array([[ 0.33100885, -0.7403206 , -0.77664625, ...,  1.        ,
#          0.        ,  0.        ],
#        [-1.17989246, -0.7403206 ,  0.1003166 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.37844688,  1.35076614, -0.48299432, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [-1.13957013, -0.7403206 ,  1.21832428, ...,  1.        ,
#          0.        ,  0.        ],
#        [-1.49772727, -0.7403206 , -0.77809567, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.52076098, -0.7403206 , -0.77976293, ...,  1.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# Building a linear regression model to predict outlet sales.

# %%
# Import the and instantiate the linear regression model
reg = LinearRegression()

# %%
#Create a modeling pipeline, using previous scaler and reg from above
line_reg_pipe = make_pipeline(scaler, reg)

# %%
#Fitting model to training data
line_reg_pipe.fit(X_train_processed,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
##Make predictions using the train and testing data.
train_pred = line_reg_pipe.predict(X_train_processed)
test_pred = line_reg_pipe.predict(X_test_processed)

# %%
reg.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %% [markdown]
# - Evaluating the performance of the linear model based on r^2.

# %%
#Using Scikit-Learn to calculate r2.
train_r2 = r2_score(y_train, train_pred)
test_r2 = r2_score(y_test, test_pred)
print(f'Model Training R2: {train_r2}')
print(f'Model Testing R2: {test_r2}')
# Out:
# Model Training R2: 0.5602435287390115
# Model Testing R2: 0.5655412905710866

# %% [markdown]
# - Evaluating the performance of the linear model based on Mean Squared Error (MSE).

# %%
#Using Scikit-Learn to calculate MSE.
train_MSE = mean_squared_error(y_train, train_pred)
test_MSE = mean_squared_error(y_test, test_pred)
print(f'Model Traing MSE: {train_MSE}')
print(f'Model Testing MSE: {test_MSE}')
# Out:
# Model Traing MSE: 1301439.797475802
# Model Testing MSE: 1198661.711804163

# %% [markdown]
# - Evaluating the performance of the linear model based on Root Mean Squared Error (RMSE).

# %%
#Using sklearn to find the MSE and just include the square root to get RMSE
train_RMSE = np.sqrt(train_MSE)
test_RMSE = np.sqrt(test_MSE)
print(f'Model training RMSE: {train_RMSE}')
print(f'Model testing RMSE: {test_RMSE}')
# Out:
# Model training RMSE: 1140.8066433343567
# Model testing RMSE: 1094.834102411942

# %% [markdown]
# Building a regression tree model to predict outlet sales.

# %%
# Import the and instantiate the regression tree model
tree_reg = RandomForestRegressor(random_state = 42)

# %%
#Create a modeling pipeline, using previous scaler and tree_reg from above
tree_reg_pipe = make_pipeline(scaler, tree_reg)

# %%
#Fitting model to training data
tree_reg_pipe.fit(X_train_processed,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=42))])

# %%
#Making predictions using the train and testing data.
tree_train_pred = tree_reg_pipe.predict(X_train_processed)
tree_test_pred = tree_reg_pipe.predict(X_test_processed)

# %%
#Checking parameters for random forest
tree_reg.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# - Evaluating the performance of the regressor tree model based on r^2.

# %%
#Using Scikit-Learn to calculate r2.
tree_train_r2 = r2_score(y_train, tree_train_pred)
tree_test_r2 = r2_score(y_test, tree_test_pred)
print(f'Model Training R2: {tree_train_r2}')
print(f'Model Testing R2: {tree_test_r2}')
# Out:
# Model Training R2: 0.937062031291833
# Model Testing R2: 0.5436785966748476

# %% [markdown]
# - Evaluating the performance of the regressor tree model based on Mean Squared Error (MSE).

# %%
#Using Scikit-Learn to calculate MSE for tree
tree_train_MSE = mean_squared_error(y_train, tree_train_pred)
tree_test_MSE = mean_squared_error(y_test, tree_test_pred)
print(f'Model Traing MSE: {tree_train_MSE}')
print(f'Model Testing MSE: {tree_test_MSE}')
# Out:
# Model Traing MSE: 186262.1305246988
# Model Testing MSE: 1258980.3877141555

# %% [markdown]
# - Evaluating the performance of the regressor tree model based on Root Mean Squared Error (RMSE).

# %%
tree_train_RMSE = np.sqrt(tree_train_MSE)
tree_test_RMSE = np.sqrt(tree_test_MSE)
print(f'Model training RMSE: {tree_train_RMSE}')
print(f'Model testing RMSE: {tree_test_RMSE}')
# Out:
# Model training RMSE: 431.5809663605414
# Model testing RMSE: 1122.0429527046438

# %% [markdown]
# Based on the 2 different models (linear & Random Forest) tested on the data set. I determined the best model to implement would be the the linear. Although, both were not amazing. I recommend the linear model for several reasons.
#
# 1. The R2 or the coefficient of determination, showed a better prediction of the test data. With
# an R2 of .56 means that the model can explain 56% of the variation in the target data.
#
# 2. The RMSE or Root Mean Squared Error had the least error diffrence in dollars. An RMSE of 1094, tells us that our model is making an average error of 1,094 dollars on the test data. While, the othere model had an average error of 1,122 dollars on the test data.
#
# 3. The Rabdom Forest model has an high variance and is overfit. Thus, predicts the training data better than linear model, but does not predict the testing data as well as the linear model.

# %% [markdown]
# ##Deep Learning Model for Predicting Sales

# %%
from sklearn.metrics import silhouette_score, accuracy_score, precision_score, recall_score

from tensorflow.keras import Sequential
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.model_selection import train_test_split

from sklearn import set_config
set_config(display='diagram')

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score

# %%
# Learning history plotting function
#Source Learn platform Week 3
def plot_history(history):
  """Takes a keras model learning history and plots each metric"""
  
  metrics = history.history.keys()
  
  for metric in metrics:
      if not 'val' in metric:
        plt.plot(history.history[f'{metric}'], label=f'{metric}')
        if f'val_{metric}' in metrics:
          plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
        plt.legend()
        plt.title(f'{metric}')
        plt.show()

# %%
X_train_processed
# Out:
# array([[ 0.81724868, -0.7403206 , -0.71277507, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.5563395 ,  1.35076614, -1.29105225, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.13151196,  1.35076614,  1.81331864, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.11373638, -0.7403206 , -0.92052713, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.76600931, -0.7403206 , -0.2277552 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.81724868, -0.7403206 , -0.95867683, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
X_train_processed.shape[1]
# Out:
# 26

# %%
#making scaler 
dl_scaler = StandardScaler()
dl_scaler.fit(X_train_processed)
# Out:
# StandardScaler()

# %%
#transform Xtrain and Xtest
X_train_sc = dl_scaler.transform(X_train_processed)
X_test_sc = dl_scaler.fit_transform(X_test_processed)

# %%
#model shape
input_shape = X_train_processed.shape[1]
input_shape
# Out:
# 26

# %% [markdown]
# **Model 1: A**

# %%
#1st model
A_model = Sequential()

# %%
# creating a model architecture
 
A_model.add(Dense(26, input_dim=input_shape, activation='relu'))
A_model.add(Dense(20, activation='relu'))
A_model.add(Dense(1, activation='linear'))

# %%
# compile model with metrics, using mse for linear model
A_model.compile(loss='mse', optimizer='adam', metrics=[ metrics.MeanAbsoluteError(),
                                                         metrics.RootMeanSquaredError()])

# %%
A_history = A_model.fit(X_train_sc, y_train,
                        validation_data=(X_test_sc, y_test),
                        epochs=15,
                        verbose=0)

# %%
# plot learning history
plot_history(A_history)

# %%
# evaluating models
 
y_pred_A = A_model.predict(X_test_sc)  

print(f'final RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_A))}')
print(f'final MAE: {mean_absolute_error(y_test, y_pred_A)}')
print(f'final R2: {r2_score(y_test, y_pred_A)}')
# Out:
# final RMSE: 1072.6667529654067
# final MAE: 765.5142894419376
# final R2: 0.5829563483532445

# %% [markdown]
# **Model 2: B**

# %%
#2nd model
B_model = Sequential()

# %%
# create model B architecture
 
B_model.add(Dense(26, input_dim=input_shape, activation='relu'))
B_model.add(Dense(20, activation='relu'))
B_model.add(Dense(10, activation='relu'))
B_model.add(Dense(5, activation='relu'))
B_model.add(Dense(1, activation='linear'))

# %%
# compile model with metrics, using mse for linear model
B_model.compile(loss='mse', optimizer='adam', metrics=[ metrics.MeanAbsoluteError(),
                                                         metrics.RootMeanSquaredError()])

# %%
B_history = B_model.fit(X_train_sc, y_train,
                        validation_data=(X_test_sc, y_test),
                        epochs=15,
                        verbose=0)

# %%
# plot learning history
plot_history(B_history)

# %%
# evaluating models
 
y_pred_B = B_model.predict(X_test_sc)  

print(f'final RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_B))}')
print(f'final MAE: {mean_absolute_error(y_test, y_pred_B)}')
print(f'final R2: {r2_score(y_test, y_pred_B)}')
# Out:
# final RMSE: 1076.3788067283688
# final MAE: 765.9300068075967
# final R2: 0.5800649245304046

# %% [markdown]
# **Model 3: C**

# %%
#3Rd model
C_model = Sequential()

# %%
# create model C architecture, with 3 Dropout of 30%
 
C_model.add(Dense(26, input_dim=input_shape, activation='relu'))
C_model.add(Dropout(0.3))
C_model.add(Dense(20, activation='relu'))
C_model.add(Dense(26, input_dim=input_shape, activation='relu'))
C_model.add(Dropout(0.3))
C_model.add(Dense(10, activation='relu'))
C_model.add(Dense(26, input_dim=input_shape, activation='relu'))
C_model.add(Dropout(0.3))
C_model.add(Dense(5, activation='relu'))
C_model.add(Dense(1, activation='linear'))

# %%
# compile model with metrics, using mse for linear model
C_model.compile(loss='mse', optimizer='adam', metrics=[ metrics.MeanAbsoluteError(),
                                                         metrics.RootMeanSquaredError()])

# %%
C_history = C_model.fit(X_train_sc, y_train,
                        validation_data=(X_test_sc, y_test),
                        epochs=15,
                        verbose=0)

# %%
# plot learning history
plot_history(C_history)

# %%
# evaluating models
 
y_pred_C = C_model.predict(X_test_sc)  

print(f'final RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_C))}')
print(f'final MAE: {mean_absolute_error(y_test, y_pred_C)}')
print(f'final R2: {r2_score(y_test, y_pred_C)}')
# Out:
# final RMSE: 1056.51779552469
# final MAE: 736.2675764287325
# final R2: 0.5954189774618492

# %% [markdown]
# **Model 4: D**

# %%
#4th model
D_model = Sequential()

# %%
# create model D architecture, with 3 Dropout of 30%
 
D_model.add(Dense(26, input_dim=input_shape, activation='relu'))
D_model.add(Dropout(0.3))
D_model.add(Dense(20, activation='relu'))
D_model.add(Dense(26, input_dim=input_shape, activation='relu'))
D_model.add(Dropout(0.3))
D_model.add(Dense(10, activation='relu'))
D_model.add(Dense(26, input_dim=input_shape, activation='relu'))
D_model.add(Dropout(0.3))
D_model.add(Dense(5, activation='relu'))
D_model.add(Dense(1, activation='linear'))

# %%
# compile model with metrics, using mse for linear model
D_model.compile(loss='mse', optimizer='adam', metrics=[ metrics.MeanAbsoluteError(),
                                                         metrics.RootMeanSquaredError()])

# %%
#making epochs higher to 30 and adding Early Stopping
early_stopping = EarlyStopping(patience=4)

D_history = D_model.fit(X_train_sc, y_train,
                        validation_data=(X_test_sc, y_test),
                        epochs=30, callbacks = [early_stopping],
                        verbose=0)

# %%
# plot learning history for D
plot_history(D_history)

# %%
# evaluating models
 
y_pred_D = D_model.predict(X_test_sc)  

print(f'final RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_D))}')
print(f'final MAE: {mean_absolute_error(y_test, y_pred_D)}')
print(f'final R2: {r2_score(y_test, y_pred_D)}')
# Out:
# final RMSE: 1070.6787235460563
# final MAE: 742.2773915197163
# final R2: 0.5845007734856905

# %% [markdown]
# ##Final Models Evaluation:

# %% [markdown]
# Best Model was:
#
# - Model C
#
#  - MAE of 736 dollars
#  - RMSE of 1056 dollars
#  - Lowest Val_loss of all models
#  - R2 of 59.5%
#
# - Based on the metrics and evaluations, it looks like to me that Model C did the best overall performance. Getting lowest MAE, RMSE, and Val_loss on the data. Although, Model D also did almost as good. What helped model D may have been the EarlyStopping, which made model D pick the lowest Val_lose when epochs was high. However, model C still did better in everything overall.
# - This deep learning model will help solve the business problem for Grocery Stores trying to predict an Items for sales. In fact, it will accurately predict close to 60% of the likelihood a product will outsell other products in the store. Which is fantastic.
